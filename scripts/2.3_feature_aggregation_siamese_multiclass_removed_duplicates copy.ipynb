# %%
import pandas as pd
import numpy as np
import os
import random
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score, roc_auc_score, average_precision_score
import gc
from tqdm import tqdm
import time
from collections import defaultdict
import copy
import matplotlib.pyplot as plt

import torch
from torch.utils.data import Dataset
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
from torch.utils.data import DataLoader, Dataset
from torch.cuda.amp import autocast, GradScaler

import pdb

import wandb

# %% [markdown]
# # Defining global parameters

# %%
def get_available_device():
    if torch.cuda.is_available():
        return "cuda"
    elif torch.backends.mps.is_available():
        return "mps"
    else:
        return "cpu"
    
CONFIG = {
    "seed": 42,
    "epochs": 12, # 42, ~MAX 20 hours of training
    "train_batch_size": 16,
    "valid_batch_size": 64,
    "learning_rate": 5e-5,
    "scheduler": 'CosineAnnealingLR',
    "min_lr": 5e-7,
    "T_max": 12,
    "weight_decay": 1e-6,
    "fold" : 0,
    "n_fold": 5,
    "n_accumulate": 1,
    "device": get_available_device(),
    'labels': ['unable_to_assess', 'not_close_match','close_match', 'near_exact_match', 'exact_match'], # 'unable_to_assess', 'not_close_match','close_match', 'near_exact_match', 'exact_match'
    'FP': 'fp', # 'fp', 'molformer', 'ECFP', 'grover'
}

def seed_everything(seed=42):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

seed_everything(seed=CONFIG['seed'])

# %% [markdown]
# # Read the data that has duplicates REMOVED
# ## Validation set of 20% of the size

# %%
train_df = pd.read_pickle('../data/train_split_remove_duplicates_all_embeddings.pkl')
valid_df = pd.read_pickle('../data/valid_split_remove_duplicates_all_embeddings.pkl')
# Out:
# [14:17:02] Depickling from a version number (16.1)that is higher than our version (15.0).
# This probably won't work.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 train_df = pd.read_pickle('../data/train_split_remove_duplicates_all_embeddings.pkl')
#       2 valid_df = pd.read_pickle('../data/valid_split_remove_duplicates_all_embeddings.pkl')
#
# File ~/anaconda3/envs/DTMS/lib/python3.8/site-packages/pandas/io/pickle.py:196, in read_pickle(filepath_or_buffer, compression, storage_options)
#     193     with warnings.catch_warnings(record=True):
#     194         # We want to silence any warnings about, e.g. moved modules.
#     195         warnings.simplefilter("ignore", Warning)
# --> 196         return pickle.load(handles.handle)
#     197 except excs_to_catch:
#     198     # e.g.
#     199     #  "No module named 'pandas.core.sparse.series'"
#     200     #  "Can't get attribute '__nat_unpickle' on <module 'pandas._libs.tslib"
#     201     return pc.load(handles.handle, encoding=None)
#
# RuntimeError: Bad pickle format: ENDMOL tag not found.

# %%
if CONFIG['FP'] == 'ECFP':
    CONFIG['input_size'] = 2048
elif CONFIG['FP'] == 'molformer':
    CONFIG['input_size'] = 768
elif CONFIG['FP'] == 'fp':
    CONFIG['input_size'] = 2215
elif CONFIG['FP'] == 'grover':
    CONFIG['input_size'] = 5000

# %% [markdown]
# ## Wrapping in Pytorch Dataset

# %%
class EnvedaDataset(Dataset):
    def __init__(self, CONFIG, dataframe, labels = []):
        """
        Args:
            dataframe (pd.DataFrame): A DataFrame containing 'ground_truth_embeddings', 
                                       'predicted_embeddings', and output columns.
        """
        self.dataframe = dataframe
        
        if CONFIG['FP'] == 'molformer':
            # Convert Molformer embeddings to tensors
            self.ground_truth_embeddings = torch.tensor(dataframe['ground_truth_embeddings'].tolist(), dtype=torch.float32)
            self.predicted_embeddings = torch.tensor(dataframe['predicted_embeddings'].tolist(), dtype=torch.float32)
    
        # fingerprints
        elif CONFIG['FP'] == 'ECFP':
            self.ground_truth_embeddings = torch.tensor(dataframe['ground_truth_ECFP'].tolist(), dtype=torch.float32)
            self.predicted_embeddings = torch.tensor(dataframe['predicted_ECFP'].tolist(), dtype=torch.float32)
        elif CONFIG['FP'] == 'fp':
            self.ground_truth_embeddings = dataframe['ground_truth_fp']
            self.predicted_embeddings = dataframe['predicted_fp']

        elif CONFIG['FP'] == 'grover':
            self.ground_truth_embeddings = torch.tensor(dataframe['ground_truth_grover_fp'].tolist(), dtype=torch.float32)
            self.predicted_embeddings = torch.tensor(dataframe['predicted_grover_fp'].tolist(), dtype=torch.float32)
    
        
        self.labels_text = labels
        # Convert labels to tensor
        self.labels = torch.tensor(dataframe[labels].values, dtype=torch.float32)

    def __len__(self):
        """Returns the total number of samples."""
        return len(self.dataframe)

    def __getitem__(self, idx):
        """Generates one sample of data."""
        if CONFIG['FP'] == 'molformer':
            return self.ground_truth_embeddings[idx].squeeze(0), self.predicted_embeddings[idx].squeeze(0), self.labels[idx]
        elif CONFIG['FP'] == 'fp':
            return self.ground_truth_embeddings.iloc[idx].squeeze(0), self.predicted_embeddings.iloc[idx].squeeze(0), self.labels[idx]
        elif CONFIG['FP'] == 'ECFP':
            return self.ground_truth_embeddings[idx], self.predicted_embeddings[idx], self.labels[idx]
        elif CONFIG['FP'] == 'grover':
            return self.ground_truth_embeddings[idx].squeeze(0), self.predicted_embeddings[idx].squeeze(0), self.labels[idx]

# %%
trainset = EnvedaDataset(CONFIG, dataframe=train_df, labels=CONFIG['labels'])
validset = EnvedaDataset(CONFIG, dataframe=valid_df, labels=CONFIG['labels'])

# %% [markdown]
# ## Wrapping in Pytorch DataLoader

# %%
trainloader, validloader = DataLoader(trainset, batch_size=CONFIG['train_batch_size']), \
                           DataLoader(validset, batch_size=CONFIG['valid_batch_size'])

# %%
gt, pred, labels = next(iter(trainloader))
print(gt.shape, pred.shape, labels.shape)
# Out:
# torch.Size([16, 2215]) torch.Size([16, 2215]) torch.Size([16, 5])

# %% [markdown]
# # Defining neural network

# %%
# Define the Siamese Network
class SiameseNetwork(nn.Module):
    def __init__(self, input_dim=768, output_dim=4):
        super(SiameseNetwork, self).__init__()

        self.fc = nn.Sequential(
        nn.Linear(input_dim, 1024),
        nn.ReLU(inplace=True),
        nn.Dropout(0.2),
        nn.Linear(1024, 512),
        nn.ReLU(inplace=True),
        nn.Dropout(0.2),
        nn.Linear(512, 256),
        nn.ReLU(inplace=True),
        nn.Dropout(0.2),
        nn.Linear(256, 128),
        nn.ReLU(inplace=True),
        nn.Dropout(0.2))

        self.fc5 = nn.Linear(128, output_dim)

        #self.fc5 = nn.Linear(16 * 2, output_dim)  # Output layer for similarity judgements

    def forward_one(self, x):
        return self.fc(x)

    def forward(self, input1, input2):
        out1 = self.forward_one(input1)
        out2 = self.forward_one(input2)
        # pdb.set_trace()
        # Combine both outputs by concatenation
        # combined = torch.concat((out1, out2), dim=1) # concatenate embeddings
        combined = torch.sub(out1, out2)  # maybe torch.abs(out1 - out2)
        output = self.fc5(combined)                  # Outputs raw logits
        return output
    
# model = SiameseNetwork()
# model(gt, pred)

# %% [markdown]
# # Training and validation regime
#
# ## Training with mixed precision, gradient accumulation, learning with scheduler
# ## Validation logging loss, AUROC, and F1 metrics

# %%
def train_one_epoch(model, optimizer, criterion, scheduler, dataloader, epoch=CONFIG['epochs']):
    model.train()
    
    scaler = GradScaler()
    dataset_size = 0
    running_loss = 0.0
    running_auroc  = 0.0
    running_f1 = 0.0
    bar = tqdm(enumerate(dataloader), total=len(dataloader))
    for step, data in bar:
        
        gt, preds, targets = data
        gt, preds, targets = gt.to(CONFIG['device']), preds.to(CONFIG['device']), targets.to(CONFIG['device'])
        batch_size = gt.shape[0]

        with autocast():
            outputs = model(gt, preds)
            loss = criterion(outputs, targets)
            loss = loss / CONFIG['n_accumulate']
            
        # Backward pass with scaling
        scaler.scale(loss).backward()
    
        if (step + 1) % CONFIG['n_accumulate'] == 0:
            # Step the optimizer
            scaler.step(optimizer)

            # Update the scale for next iteration
            scaler.update()
            # optimizer.step()

            # zero the parameter gradients
            optimizer.zero_grad()

            if scheduler is not None:
                scheduler.step()
        
        # pdb.set_trace()
        probabilities = torch.softmax(outputs, dim=1).detach().cpu().numpy() if outputs.shape[1] > 1 else torch.sigmoid(outputs).detach().cpu().numpy()
        preds = np.eye(outputs.shape[1])[np.argmax(probabilities, axis=1)] if outputs.shape[1] > 1 else (probabilities > 0.5).astype(float)
        # pdb.set_trace()
        auroc = average_precision_score(targets.cpu().numpy(), probabilities)
        f1 = f1_score(targets.cpu().numpy(), preds, average='weighted')
        
        running_loss += (loss.item() * batch_size)
        running_auroc  += (auroc * batch_size)
        running_f1 += (f1 * batch_size)
        dataset_size += batch_size
        
        epoch_loss = running_loss / dataset_size
        epoch_auroc = running_auroc / dataset_size
        epoch_f1 = running_f1 / dataset_size
        
        bar.set_postfix(Epoch=epoch, Train_Loss=epoch_loss, Train_Auroc=epoch_auroc, Train_F1=epoch_f1,
                        LR=optimizer.param_groups[0]['lr'])
    gc.collect()
    
    return epoch_loss, epoch_auroc, epoch_f1

@torch.no_grad()
def valid_one_epoch(model, dataloader, criterion, epoch):
    model.eval()
    
    dataset_size = 0
    running_loss = 0.0
    running_auroc = 0.0
    running_f1 = 0.0 
    
    bar = tqdm(enumerate(dataloader), total=len(dataloader))
    for step, data in bar:
        
        gt, preds, targets = data
        gt, preds, targets = gt.to(CONFIG['device']), preds.to(CONFIG['device']), targets.to(CONFIG['device'])
        batch_size = gt.shape[0]
        
        with autocast():
            outputs = model(gt, preds)
            loss = criterion(outputs, targets)
            loss = loss / CONFIG['n_accumulate']
        
        probabilities = torch.softmax(outputs, dim=1).detach().cpu().numpy() if outputs.shape[1] > 1 else torch.sigmoid(outputs).detach().cpu().numpy()
        preds = np.eye(outputs.shape[1])[np.argmax(probabilities, axis=1)] if outputs.shape[1] > 1 else (probabilities > 0.5).astype(float)
        
        auroc = average_precision_score(targets.cpu().numpy(), probabilities, average='weighted')
        f1 = f1_score(targets.cpu().numpy(), preds, average='weighted')
        
        running_loss += (loss.item() * batch_size)
        running_auroc  += (auroc * batch_size)
        running_f1 += (f1 * batch_size)
        dataset_size += batch_size
        
        epoch_loss = running_loss / dataset_size
        epoch_auroc = running_auroc / dataset_size
        epoch_f1 = running_f1 / dataset_size
        
        bar.set_postfix(Epoch=epoch, Valid_Loss=epoch_loss, Valid_Auroc=epoch_auroc, 
                        Valid_F1=epoch_f1,
                        )   
    gc.collect()
    
    return epoch_loss, epoch_auroc, epoch_f1

# %% [markdown]
# ## Initializing components
# 1. Model
# 2. AdamW optimizer
# 3. Cosine annealing scheduler
# 4. Weighted cross entropy loss to handle class imbalance

# %%
model = SiameseNetwork(input_dim=CONFIG['input_size'], output_dim=len(CONFIG['labels'])).to(CONFIG['device'])
optimizer = optim.AdamW(model.parameters(), lr=CONFIG['learning_rate'], 
                       weight_decay=CONFIG['weight_decay'])
scheduler = lr_scheduler.CosineAnnealingLR(optimizer,T_max=CONFIG['T_max'], 
                                                   eta_min=CONFIG['min_lr'])


class_distribution = {'unable_to_assess': 73, 
                      'not_close_match': 556,
                      'close_match': 605, 
                      'near_exact_match': 360, 
                      'exact_match': 73}

# Calculate class weights
total_samples = sum(class_distribution.values())
class_weights = {label: total_samples / (len(class_distribution) * count) for label, count in class_distribution.items()}

# Convert weights to a tensor
weights = torch.tensor([class_weights['unable_to_assess'],
                        class_weights['not_close_match'],
                        class_weights['close_match'],
                        class_weights['near_exact_match'],
                        class_weights['exact_match']], dtype=torch.float32).to(CONFIG['device'])

# find the indeces of keys in class_distribution in CONFIG['labels']
weights = torch.tensor([class_weights[c] for c in CONFIG['labels']], dtype=torch.float32).to(CONFIG['device'])

# Modify the loss function in your training loop
criterion = nn.CrossEntropyLoss(weight=weights)

# %%
# train_one_epoch(model=model, optimizer=optimizer, criterion=criterion, scheduler=scheduler, dataloader=trainloader)
# valid_one_epoch(model=model, dataloader=trainloader, criterion=criterion, epoch=CONFIG['epochs'])

# %% [markdown]
# ## Putting all together into training code
# Training code includes:
# 1. Early stopping
# 2. Saving best model weights according to supplied name
# 3. Original code adapted from Kaggle

# %%
def run_training(model, optimizer, scheduler, criterion, num_epochs, train_loader, valid_loader, name):

    if torch.cuda.is_available():
        print("[INFO] Using GPU: {}\n".format(torch.cuda.get_device_name()))

    directory = '../results/' # for saving models/results
    
    start = time.time()
    best_model_wts = copy.deepcopy(model.state_dict())
    best_epoch_f1 = -np.inf
    best_valid_loss = np.inf
    history = defaultdict(list)
    
    for epoch in range(1, num_epochs + 1): 
        gc.collect()
        train_epoch_loss, train_epoch_auroc, train_epoch_f1 = train_one_epoch(model=model, optimizer=optimizer, scheduler=scheduler, 
                                           criterion=criterion, dataloader=train_loader, 
                                           epoch=epoch)
        
        val_epoch_loss, val_epoch_auroc, val_epoch_f1 = valid_one_epoch(model=model, dataloader=valid_loader, criterion=criterion, 
                                         epoch=epoch)
    
        history['Train Loss'].append(train_epoch_loss)
        history['Valid Loss'].append(val_epoch_loss)
        history['Train AUROC'].append(train_epoch_auroc)
        history['Valid AUROC'].append(val_epoch_auroc)
        history['Valid F1'].append(val_epoch_f1)
        history['lr'].append( scheduler.get_lr()[0] )

        wandb.log({
            "Train Loss": train_epoch_loss,
            "Valid Loss": val_epoch_loss,
            "Train AUROC": train_epoch_auroc,
            "Valid AUROC": val_epoch_auroc,
            "Valid F1": val_epoch_f1,
            "lr": scheduler.get_lr()[0]
        })

        if val_epoch_loss <= best_valid_loss:
            print(f"Validation Loss Improved ({best_valid_loss} ---> {val_epoch_loss})")
            best_valid_loss = val_epoch_loss
            best_model_wts = copy.deepcopy(model.state_dict())
            PATH = directory + f"best_VAL_LOSS_model_{name}.bin"
            torch.save(model.state_dict(), PATH)
            # Save a model file from the current directory
            print(f"Model Saved")
        
        if best_epoch_f1 <= val_epoch_f1:
            print(f"Validation F1 Improved ({best_epoch_f1} ---> {val_epoch_f1})")
            best_epoch_f1 = val_epoch_f1
            best_model_wts = copy.deepcopy(model.state_dict())
            PATH = directory + f"best_F1_model_{name}.bin"
            torch.save(model.state_dict(), PATH)
            # Save a model file from the current directory
            print(f"Model Saved")
            
        print()
    
    end = time.time()
    time_elapsed = end - start
    print('Training complete in {:.0f}h {:.0f}m {:.0f}s'.format(
        time_elapsed // 3600, (time_elapsed % 3600) // 60, (time_elapsed % 3600) % 60))
    print("Best F1: {:.4f}".format(best_epoch_f1))
    print("Best Loss: {:.4f}".format(best_valid_loss))
    
    # load best model weights
    model.load_state_dict(best_model_wts)
    
    return model, history

# %% [markdown]
# # Runs

# %%
wandb.login()
# Out:
# True

# %%
CONFIG['dropout'] = 0.2
CONFIG['epochs'] = 200

# start a new wandb run to track this script
wandb.init(
    # set the wandb project where this run will be logged
    project="siamese_network",
    name="1class_sub_drop_FP_Lnet_AUROCweighted",

    # track hyperparameters and run metadata
    config=CONFIG
)

# Track gradients and log the model architecture
wandb.watch(model, log="all")
# Out:
# wandb version 0.18.5 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.1
# Run data is saved locally in <code>/Users/david/Documents/Projects/DT/Code/biohack/scripts/wandb/run-20241018_111033-bf0tnlzl</code>
# Syncing run <strong><a href='https://wandb.ai/davidkubanek/siamese_network/runs/bf0tnlzl' target="_blank">1class_sub_drop_FP_Lnet_AUROCweighted</a></strong> to <a href='https://wandb.ai/davidkubanek/siamese_network' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/davidkubanek/siamese_network' target="_blank">https://wandb.ai/davidkubanek/siamese_network</a>
#  View run at <a href='https://wandb.ai/davidkubanek/siamese_network/runs/bf0tnlzl' target="_blank">https://wandb.ai/davidkubanek/siamese_network/runs/bf0tnlzl</a>
# []

# %%
model, history = run_training(model=model, optimizer=optimizer, 
                              scheduler=scheduler, criterion=criterion, 
                              num_epochs=CONFIG['epochs'], train_loader=trainloader, valid_loader=validloader, 
                              name='siamese_multiclass_sub')

wandb.finish()
# Out:
# /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/cuda/amp/grad_scaler.py:125: UserWarning: torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.
#   warnings.warn(
#   0%|          | 0/84 [00:00<?, ?it/s]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:979: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
#   1%|          | 1/84 [00:01<02:42,  1.96s/it, Epoch=1, LR=4.92e-5, Train_Auroc=0, Train_F1=0.968, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
#   1%|          | 1/84 [00:01<02:42,  1.96s/it, Epoch=1, LR=4.67e-5, Train_Auroc=0.0417, Train_F1=0.938, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:979: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
#   1%|          | 1/84 [00:02<02:42,  1.96s/it, Epoch=1, LR=4.28e-5, Train_Auroc=0.0278, Train_F1=0.958, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:979: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
#   1%|          | 1/84 [00:02<02:42,  1.96s/it, Epoch=1, LR=3.76e-5, Train_Auroc=0.0208, Train_F1=0.969, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
#   1%|          | 1/84 [00:02<02:42,  1.96s/it, Epoch=1, LR=3.17e-5, Train_Auroc=0.0448, Train_F1=0.938, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:979: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
#   7%|▋         | 6/84 [00:02<00:20,  3.84it/s, Epoch=1, LR=2.52e-5, Train_Auroc=0.0374, Train_F1=0.949, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
#   7%|▋         | 6/84 [00:02<00:20,  3.84it/s, Epoch=1, LR=1.88e-5, Train_Auroc=0.0499, Train_F1=0.943, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:979: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
#   7%|▋         | 6/84 [00:02<00:20,  3.84it/s, Epoch=1, LR=1.29e-5, Train_Auroc=0.0437, Train_F1=0.95, Train_Loss=0] /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
#   7%|▋         | 6/84 [00:02<00:20,  3.84it/s, Epoch=1, LR=7.75e-6, Train_Auroc=0.0518, Train_F1=0.935, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
#  12%|█▏        | 10/84 [00:02<00:10,  6.78it/s, Epoch=1, LR=3.82e-6, Train_Auroc=0.064, Train_F1=0.923, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:979: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
#  12%|█▏        | 10/84 [00:02<00:10,  6.78it/s, Epoch=1, LR=1.34e-6, Train_Auroc=0.0581, Train_F1=0.93, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:979: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
#  12%|█▏        | 10/84 [00:02<00:10,  6.78it/s, Epoch=1, LR=5e-7, Train_Auroc=0.0533, Train_F1=0.936, Train_Loss=0]  /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:979: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
#  15%|█▌        | 13/84 [00:02<00:07,  9.03it/s, Epoch=1, LR=1.34e-6, Train_Auroc=0.0492, Train_F1=0.938, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:979: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
#  15%|█▌        | 13/84 [00:02<00:07,  9.03it/s, Epoch=1, LR=3.82e-6, Train_Auroc=0.0457, Train_F1=0.941, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
#  15%|█▌        | 13/84 [00:02<00:07,  9.03it/s, Epoch=1, LR=7.75e-6, Train_Auroc=0.0598, Train_F1=0.932, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:979: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
#  19%|█▉        | 16/84 [00:02<00:05, 11.56it/s, Epoch=1, LR=1.29e-5, Train_Auroc=0.0561, Train_F1=0.937, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:979: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
#  19%|█▉        | 16/84 [00:02<00:05, 11.56it/s, Epoch=1, LR=1.88e-5, Train_Auroc=0.0528, Train_F1=0.94, Train_Loss=0] /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:979: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
#  19%|█▉        | 16/84 [00:02<00:05, 11.56it/s, Epoch=1, LR=2.52e-5, Train_Auroc=0.0498, Train_F1=0.944, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:979: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
#  19%|█▉        | 16/84 [00:02<00:05, 11.56it/s, Epoch=1, LR=3.17e-5, Train_Auroc=0.0472, Train_F1=0.947, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:979: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
#  24%|██▍       | 20/84 [00:02<00:04, 15.37it/s, Epoch=1, LR=3.76e-5, Train_Auroc=0.0449, Train_F1=0.949, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
#  24%|██▍       | 20/84 [00:02<00:04, 15.37it/s, Epoch=1, LR=4.28e-5, Train_Auroc=0.054, Train_F1=0.943, Train_Loss=0] /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:979: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
#  24%|██▍       | 20/84 [00:02<00:04, 15.37it/s, Epoch=1, LR=4.67e-5, Train_Auroc=0.0515, Train_F1=0.946, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
#  24%|██▍       | 20/84 [00:02<00:04, 15.37it/s, Epoch=1, LR=4.92e-5, Train_Auroc=0.0536, Train_F1=0.944, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:979: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
#  29%|██▊       | 24/84 [00:02<00:03, 19.65it/s, Epoch=1, LR=5e-5, Train_Auroc=0.0514, Train_F1=0.946, Train_Loss=0]   /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
#  29%|██▊       | 24/84 [00:02<00:03, 19.65it/s, Epoch=1, LR=4.92e-5, Train_Auroc=0.0601, Train_F1=0.937, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:979: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
#  29%|██▊       | 24/84 [00:02<00:03, 19.65it/s, Epoch=1, LR=4.67e-5, Train_Auroc=0.0578, Train_F1=0.94, Train_Loss=0] /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:979: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
#  29%|██▊       | 24/84 [00:02<00:03, 19.65it/s, Epoch=1, LR=4.28e-5, Train_Auroc=0.0556, Train_F1=0.942, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:979: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
#  29%|██▊       | 24/84 [00:02<00:03, 19.65it/s, Epoch=1, LR=3.76e-5, Train_Auroc=0.0536, Train_F1=0.944, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:979: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
#  35%|███▍      | 29/84 [00:02<00:02, 24.66it/s, Epoch=1, LR=3.17e-5, Train_Auroc=0.0518, Train_F1=0.946, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
#  35%|███▍      | 29/84 [00:02<00:02, 24.66it/s, Epoch=1, LR=2.53e-5, Train_Auroc=0.0578, Train_F1=0.942, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
#  35%|███▍      | 29/84 [00:02<00:02, 24.66it/s, Epoch=1, LR=1.88e-5, Train_Auroc=0.0585, Train_F1=0.941, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
#  35%|███▍      | 29/84 [00:02<00:02, 24.66it/s, Epoch=1, LR=1.29e-5, Train_Auroc=0.0592, Train_F1=0.94, Train_Loss=0] /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:979: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
#  39%|███▉      | 33/84 [00:03<00:02, 20.39it/s, Epoch=1, LR=7.75e-6, Train_Auroc=0.0574, Train_F1=0.94, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:979: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
#  39%|███▉      | 33/84 [00:03<00:02, 20.39it/s, Epoch=1, LR=3.82e-6, Train_Auroc=0.0557, Train_F1=0.942, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
#  39%|███▉      | 33/84 [00:03<00:02, 20.39it/s, Epoch=1, LR=1.34e-6, Train_Auroc=0.0609, Train_F1=0.939, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
#  43%|████▎     | 36/84 [00:03<00:02, 16.08it/s, Epoch=1, LR=5e-7, Train_Auroc=0.0648, Train_F1=0.938, Train_Loss=0]   /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
#  43%|████▎     | 36/84 [00:03<00:02, 16.08it/s, Epoch=1, LR=1.34e-6, Train_Auroc=0.0698, Train_F1=0.937, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
#  43%|████▎     | 36/84 [00:03<00:02, 16.08it/s, Epoch=1, LR=3.82e-6, Train_Auroc=0.0767, Train_F1=0.936, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:979: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
#  46%|████▋     | 39/84 [00:03<00:03, 14.56it/s, Epoch=1, LR=7.75e-6, Train_Auroc=0.0747, Train_F1=0.936, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
#  46%|████▋     | 39/84 [00:03<00:03, 14.56it/s, Epoch=1, LR=1.29e-5, Train_Auroc=0.0754, Train_F1=0.935, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
#  46%|████▋     | 39/84 [00:03<00:03, 14.56it/s, Epoch=1, LR=1.88e-5, Train_Auroc=0.08, Train_F1=0.932, Train_Loss=0]  /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:979: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
#  46%|████▋     | 39/84 [00:03<00:03, 14.56it/s, Epoch=1, LR=2.53e-5, Train_Auroc=0.0781, Train_F1=0.933, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:979: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
#  46%|████▋     | 39/84 [00:03<00:03, 14.56it/s, Epoch=1, LR=3.17e-5, Train_Auroc=0.0763, Train_F1=0.935, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
#  52%|█████▏    | 44/84 [00:03<00:02, 19.69it/s, Epoch=1, LR=3.76e-5, Train_Auroc=0.0761, Train_F1=0.934, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:979: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
#  52%|█████▏    | 44/84 [00:03<00:02, 19.69it/s, Epoch=1, LR=4.28e-5, Train_Auroc=0.0744, Train_F1=0.935, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
#  52%|█████▏    | 44/84 [00:03<00:02, 19.69it/s, Epoch=1, LR=4.67e-5, Train_Auroc=0.0748, Train_F1=0.934, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
#  52%|█████▏    | 44/84 [00:03<00:02, 19.69it/s, Epoch=1, LR=4.92e-5, Train_Auroc=0.076, Train_F1=0.931, Train_Loss=0] /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:979: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
#  52%|█████▏    | 44/84 [00:03<00:02, 19.69it/s, Epoch=1, LR=5e-5, Train_Auroc=0.0744, Train_F1=0.933, Train_Loss=0]  /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
#  58%|█████▊    | 49/84 [00:03<00:01, 24.57it/s, Epoch=1, LR=4.92e-5, Train_Auroc=0.0748, Train_F1=0.931, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:979: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
#  58%|█████▊    | 49/84 [00:03<00:01, 24.57it/s, Epoch=1, LR=4.67e-5, Train_Auroc=0.0733, Train_F1=0.932, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
#  58%|█████▊    | 49/84 [00:03<00:01, 24.57it/s, Epoch=1, LR=4.28e-5, Train_Auroc=0.074, Train_F1=0.932, Train_Loss=0] /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:979: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
#  58%|█████▊    | 49/84 [00:03<00:01, 24.57it/s, Epoch=1, LR=3.76e-5, Train_Auroc=0.0726, Train_F1=0.932, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
#  58%|█████▊    | 49/84 [00:03<00:01, 24.57it/s, Epoch=1, LR=3.17e-5, Train_Auroc=0.0734, Train_F1=0.93, Train_Loss=0] /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
#  64%|██████▍   | 54/84 [00:03<00:01, 29.19it/s, Epoch=1, LR=2.53e-5, Train_Auroc=0.0766, Train_F1=0.93, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:979: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
#  64%|██████▍   | 54/84 [00:03<00:01, 29.19it/s, Epoch=1, LR=1.88e-5, Train_Auroc=0.0752, Train_F1=0.93, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
#  64%|██████▍   | 54/84 [00:04<00:01, 29.19it/s, Epoch=1, LR=1.29e-5, Train_Auroc=0.0761, Train_F1=0.93, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:979: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
#  64%|██████▍   | 54/84 [00:04<00:01, 29.19it/s, Epoch=1, LR=7.75e-6, Train_Auroc=0.0748, Train_F1=0.931, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:979: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
#  64%|██████▍   | 54/84 [00:04<00:01, 29.19it/s, Epoch=1, LR=3.82e-6, Train_Auroc=0.0735, Train_F1=0.932, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:979: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
#  70%|███████   | 59/84 [00:04<00:00, 32.90it/s, Epoch=1, LR=1.34e-6, Train_Auroc=0.0723, Train_F1=0.933, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
#  70%|███████   | 59/84 [00:04<00:00, 32.90it/s, Epoch=1, LR=5e-7, Train_Auroc=0.0738, Train_F1=0.933, Train_Loss=0]   /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
#  70%|███████   | 59/84 [00:04<00:00, 32.90it/s, Epoch=1, LR=1.34e-6, Train_Auroc=0.075, Train_F1=0.93, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
#  70%|███████   | 59/84 [00:04<00:00, 32.90it/s, Epoch=1, LR=3.82e-6, Train_Auroc=0.075, Train_F1=0.93, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:979: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
#  70%|███████   | 59/84 [00:04<00:00, 32.90it/s, Epoch=1, LR=7.75e-6, Train_Auroc=0.0739, Train_F1=0.931, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:979: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
#  76%|███████▌  | 64/84 [00:04<00:00, 36.36it/s, Epoch=1, LR=1.29e-5, Train_Auroc=0.0727, Train_F1=0.932, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
#  76%|███████▌  | 64/84 [00:04<00:00, 36.36it/s, Epoch=1, LR=1.88e-5, Train_Auroc=0.075, Train_F1=0.93, Train_Loss=0]  /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
#  76%|███████▌  | 64/84 [00:04<00:00, 36.36it/s, Epoch=1, LR=2.53e-5, Train_Auroc=0.0777, Train_F1=0.93, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
#  76%|███████▌  | 64/84 [00:04<00:00, 36.36it/s, Epoch=1, LR=3.17e-5, Train_Auroc=0.0794, Train_F1=0.928, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:979: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
#  76%|███████▌  | 64/84 [00:04<00:00, 36.36it/s, Epoch=1, LR=3.76e-5, Train_Auroc=0.0783, Train_F1=0.929, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
#  82%|████████▏ | 69/84 [00:04<00:00, 26.72it/s, Epoch=1, LR=4.28e-5, Train_Auroc=0.0781, Train_F1=0.929, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:979: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
#  82%|████████▏ | 69/84 [00:04<00:00, 26.72it/s, Epoch=1, LR=4.67e-5, Train_Auroc=0.077, Train_F1=0.93, Train_Loss=0]  /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
#  82%|████████▏ | 69/84 [00:04<00:00, 26.72it/s, Epoch=1, LR=4.92e-5, Train_Auroc=0.0787, Train_F1=0.93, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
#  82%|████████▏ | 69/84 [00:04<00:00, 26.72it/s, Epoch=1, LR=5e-5, Train_Auroc=0.0786, Train_F1=0.929, Train_Loss=0]  /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
#  82%|████████▏ | 69/84 [00:04<00:00, 26.72it/s, Epoch=1, LR=4.92e-5, Train_Auroc=0.0828, Train_F1=0.927, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:979: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
#  88%|████████▊ | 74/84 [00:04<00:00, 29.88it/s, Epoch=1, LR=4.67e-5, Train_Auroc=0.0817, Train_F1=0.928, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
#  88%|████████▊ | 74/84 [00:04<00:00, 29.88it/s, Epoch=1, LR=4.28e-5, Train_Auroc=0.0816, Train_F1=0.927, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
#  88%|████████▊ | 74/84 [00:04<00:00, 29.88it/s, Epoch=1, LR=3.76e-5, Train_Auroc=0.0834, Train_F1=0.925, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
#  88%|████████▊ | 74/84 [00:04<00:00, 29.88it/s, Epoch=1, LR=3.17e-5, Train_Auroc=0.0839, Train_F1=0.924, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:979: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
#  93%|█████████▎| 78/84 [00:04<00:00, 30.53it/s, Epoch=1, LR=2.53e-5, Train_Auroc=0.0828, Train_F1=0.925, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
#  93%|█████████▎| 78/84 [00:04<00:00, 30.53it/s, Epoch=1, LR=1.88e-5, Train_Auroc=0.0836, Train_F1=0.925, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
#  93%|█████████▎| 78/84 [00:04<00:00, 30.53it/s, Epoch=1, LR=1.29e-5, Train_Auroc=0.0854, Train_F1=0.924, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
#  93%|█████████▎| 78/84 [00:04<00:00, 30.53it/s, Epoch=1, LR=7.75e-6, Train_Auroc=0.0853, Train_F1=0.924, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
#  93%|█████████▎| 78/84 [00:04<00:00, 30.53it/s, Epoch=1, LR=3.82e-6, Train_Auroc=0.0965, Train_F1=0.923, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
#  99%|█████████▉| 83/84 [00:04<00:00, 33.68it/s, Epoch=1, LR=1.34e-6, Train_Auroc=0.104, Train_F1=0.922, Train_Loss=0] /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:979: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# 100%|██████████| 84/84 [00:05<00:00, 15.88it/s, Epoch=1, LR=5e-7, Train_Auroc=0.104, Train_F1=0.922, Train_Loss=0]
#   0%|          | 0/6 [00:00<?, ?it/s]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
#   0%|          | 0/6 [00:00<?, ?it/s, Epoch=1, Valid_Auroc=0.0476, Valid_F1=0.977, Valid_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
#   0%|          | 0/6 [00:00<?, ?it/s, Epoch=1, Valid_Auroc=0.0863, Valid_F1=0.977, Valid_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:979: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
#   0%|          | 0/6 [00:00<?, ?it/s, Epoch=1, Valid_Auroc=0.0575, Valid_F1=0.984, Valid_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
#   0%|          | 0/6 [00:00<?, ?it/s, Epoch=1, Valid_Auroc=0.0974, Valid_F1=0.971, Valid_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
#   0%|          | 0/6 [00:00<?, ?it/s, Epoch=1, Valid_Auroc=0.103, Valid_F1=0.972, Valid_Loss=0] /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# 100%|██████████| 6/6 [00:00<00:00, 44.91it/s, Epoch=1, Valid_Auroc=0.125, Valid_F1=0.964, Valid_Loss=0]
# /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/optim/lr_scheduler.py:809: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   warnings.warn("To get the last learning rate computed by the scheduler, "
# Validation Loss Improved (inf ---> 0.0)
# Model Saved
# Validation F1 Improved (-inf ---> 0.9644453116782788)
# /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/cuda/amp/grad_scaler.py:125: UserWarning: torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.
#   warnings.warn(
# Model Saved
#   0%|          | 0/84 [00:00<?, ?it/s]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:979: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
#   0%|          | 0/84 [00:00<?, ?it/s, Epoch=2, LR=1.34e-6, Train_Auroc=0, Train_F1=1, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
#   0%|          | 0/84 [00:00<?, ?it/s, Epoch=2, LR=3.82e-6, Train_Auroc=0.0625, Train_F1=0.954, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:979: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
#   0%|          | 0/84 [00:00<?, ?it/s, Epoch=2, LR=7.75e-6, Train_Auroc=0.0417, Train_F1=0.969, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:979: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
#   5%|▍         | 4/84 [00:00<00:02, 34.37it/s, Epoch=2, LR=1.29e-5, Train_Auroc=0.0312, Train_F1=0.977, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
#   5%|▍         | 4/84 [00:00<00:02, 34.37it/s, Epoch=2, LR=1.88e-5, Train_Auroc=0.0893, Train_F1=0.945, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:979: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
#   5%|▍         | 4/84 [00:00<00:02, 34.37it/s, Epoch=2, LR=2.52e-5, Train_Auroc=0.0744, Train_F1=0.949, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
#   5%|▍         | 4/84 [00:00<00:02, 34.37it/s, Epoch=2, LR=3.17e-5, Train_Auroc=0.0923, Train_F1=0.938, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:979: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
#   5%|▍         | 4/84 [00:00<00:02, 34.37it/s, Epoch=2, LR=3.76e-5, Train_Auroc=0.0808, Train_F1=0.946, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
#  11%|█         | 9/84 [00:00<00:01, 38.30it/s, Epoch=2, LR=4.28e-5, Train_Auroc=0.109, Train_F1=0.931, Train_Loss=0] /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
#  11%|█         | 9/84 [00:00<00:01, 38.30it/s, Epoch=2, LR=4.67e-5, Train_Auroc=0.133, Train_F1=0.917, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:979: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
#  11%|█         | 9/84 [00:00<00:01, 38.30it/s, Epoch=2, LR=4.92e-5, Train_Auroc=0.121, Train_F1=0.921, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:979: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
#  11%|█         | 9/84 [00:00<00:01, 38.30it/s, Epoch=2, LR=5e-5, Train_Auroc=0.111, Train_F1=0.928, Train_Loss=0]   /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:979: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
#  15%|█▌        | 13/84 [00:00<00:02, 34.28it/s, Epoch=2, LR=4.92e-5, Train_Auroc=0.102, Train_F1=0.934, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:979: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
#  15%|█▌        | 13/84 [00:00<00:02, 34.28it/s, Epoch=2, LR=4.67e-5, Train_Auroc=0.095, Train_F1=0.938, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
#  15%|█▌        | 13/84 [00:00<00:02, 34.28it/s, Epoch=2, LR=4.28e-5, Train_Auroc=0.097, Train_F1=0.93, Train_Loss=0] /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:979: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
#  15%|█▌        | 13/84 [00:00<00:02, 34.28it/s, Epoch=2, LR=3.76e-5, Train_Auroc=0.0909, Train_F1=0.935, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:979: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
#  20%|██        | 17/84 [00:00<00:02, 28.74it/s, Epoch=2, LR=3.17e-5, Train_Auroc=0.0856, Train_F1=0.938, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:979: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
#  20%|██        | 17/84 [00:00<00:02, 28.74it/s, Epoch=2, LR=2.52e-5, Train_Auroc=0.0808, Train_F1=0.94, Train_Loss=0] /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:979: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
#  20%|██        | 17/84 [00:00<00:02, 28.74it/s, Epoch=2, LR=1.88e-5, Train_Auroc=0.0766, Train_F1=0.94, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:979: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
#  20%|██        | 17/84 [00:00<00:02, 28.74it/s, Epoch=2, LR=1.29e-5, Train_Auroc=0.0727, Train_F1=0.943, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
#  20%|██        | 17/84 [00:00<00:02, 28.74it/s, Epoch=2, LR=7.75e-6, Train_Auroc=0.0848, Train_F1=0.937, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:979: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
#  26%|██▌       | 22/84 [00:00<00:01, 33.18it/s, Epoch=2, LR=3.82e-6, Train_Auroc=0.081, Train_F1=0.94, Train_Loss=0]  /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
#  26%|██▌       | 22/84 [00:00<00:01, 33.18it/s, Epoch=2, LR=1.34e-6, Train_Auroc=0.0837, Train_F1=0.937, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:979: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# ...
#   warnings.warn(
#  63%|██████▎   | 53/84 [00:01<00:00, 35.34it/s, Epoch=78, LR=3.76e-5, Train_Auroc=0.107, Train_F1=0.931, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:979: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
#  63%|██████▎   | 53/84 [00:01<00:00, 35.34it/s, Epoch=78, LR=4.28e-5, Train_Auroc=0.105, Train_F1=0.932, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:979: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
#  69%|██████▉   | 58/84 [00:01<00:00, 37.44it/s, Epoch=78, LR=4.67e-5, Train_Auroc=0.103, Train_F1=0.934, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:979: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
#  69%|██████▉   | 58/84 [00:01<00:00, 37.44it/s, Epoch=78, LR=4.92e-5, Train_Auroc=0.102, Train_F1=0.934, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
#  69%|██████▉   | 58/84 [00:01<00:00, 37.44it/s, Epoch=78, LR=5e-5, Train_Auroc=0.102, Train_F1=0.934, Train_Loss=0]   /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
#  69%|██████▉   | 58/84 [00:01<00:00, 37.44it/s, Epoch=78, LR=4.92e-5, Train_Auroc=0.103, Train_F1=0.932, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
#  69%|██████▉   | 58/84 [00:01<00:00, 37.44it/s, Epoch=78, LR=4.67e-5, Train_Auroc=0.103, Train_F1=0.931, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:979: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
#  75%|███████▌  | 63/84 [00:01<00:00, 38.88it/s, Epoch=78, LR=4.28e-5, Train_Auroc=0.101, Train_F1=0.933, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:979: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
#  75%|███████▌  | 63/84 [00:01<00:00, 38.88it/s, Epoch=78, LR=3.76e-5, Train_Auroc=0.0995, Train_F1=0.934, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
#  75%|███████▌  | 63/84 [00:01<00:00, 38.88it/s, Epoch=78, LR=3.17e-5, Train_Auroc=0.0999, Train_F1=0.932, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
#  75%|███████▌  | 63/84 [00:01<00:00, 38.88it/s, Epoch=78, LR=2.52e-5, Train_Auroc=0.0999, Train_F1=0.931, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
#  75%|███████▌  | 63/84 [00:01<00:00, 38.88it/s, Epoch=78, LR=1.88e-5, Train_Auroc=0.102, Train_F1=0.93, Train_Loss=0]  /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:979: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
#  81%|████████  | 68/84 [00:01<00:00, 39.34it/s, Epoch=78, LR=1.29e-5, Train_Auroc=0.101, Train_F1=0.93, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
#  81%|████████  | 68/84 [00:01<00:00, 39.34it/s, Epoch=78, LR=7.75e-6, Train_Auroc=0.101, Train_F1=0.93, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:979: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
#  81%|████████  | 68/84 [00:02<00:00, 39.34it/s, Epoch=78, LR=3.82e-6, Train_Auroc=0.0993, Train_F1=0.931, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
#  81%|████████  | 68/84 [00:02<00:00, 39.34it/s, Epoch=78, LR=1.34e-6, Train_Auroc=0.0987, Train_F1=0.931, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
#  86%|████████▌ | 72/84 [00:02<00:00, 35.65it/s, Epoch=78, LR=5e-7, Train_Auroc=0.0988, Train_F1=0.93, Train_Loss=0]    /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
#  86%|████████▌ | 72/84 [00:02<00:00, 35.65it/s, Epoch=78, LR=1.34e-6, Train_Auroc=0.1, Train_F1=0.927, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:979: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
#  86%|████████▌ | 72/84 [00:02<00:00, 35.65it/s, Epoch=78, LR=3.82e-6, Train_Auroc=0.0987, Train_F1=0.928, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
#  86%|████████▌ | 72/84 [00:02<00:00, 35.65it/s, Epoch=78, LR=7.75e-6, Train_Auroc=0.101, Train_F1=0.928, Train_Loss=0] /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
#  90%|█████████ | 76/84 [00:02<00:00, 33.47it/s, Epoch=78, LR=1.29e-5, Train_Auroc=0.103, Train_F1=0.926, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
#  90%|█████████ | 76/84 [00:02<00:00, 33.47it/s, Epoch=78, LR=1.88e-5, Train_Auroc=0.103, Train_F1=0.925, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# /Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:979: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
#  90%|█████████ | 76/84 [00:02<00:00, 33.47it/s, Epoch=78, LR=2.53e-5, Train_Auroc=0.101, Train_F1=0.926, Train_Loss=0]/Users/david/anaconda3/envs/DTMS/lib/python3.8/site-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
#  93%|█████████▎| 78/84 [00:02<00:00, 33.74it/s, Epoch=78, LR=3.17e-5, Train_Auroc=0.101, Train_F1=0.926, Train_Loss=0]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[152], line 1
# ----> 1 model, history = run_training(model=model, optimizer=optimizer,
#       2                               scheduler=scheduler, criterion=criterion,
#       3                               num_epochs=CONFIG['epochs'], train_loader=trainloader, valid_loader=validloader,
#       4                               name='siamese_multiclass_sub')
#       6 wandb.finish()
#
# Cell In[150], line 16, in run_training(model, optimizer, scheduler, criterion, num_epochs, train_loader, valid_loader, name)
#      14 for epoch in range(1, num_epochs + 1):
#      15     gc.collect()
# ---> 16     train_epoch_loss, train_epoch_auroc, train_epoch_f1 = train_one_epoch(model=model, optimizer=optimizer, scheduler=scheduler,
#      17                                        criterion=criterion, dataloader=train_loader,
#      18                                        epoch=epoch)
#      20     val_epoch_loss, val_epoch_auroc, val_epoch_f1 = valid_one_epoch(model=model, dataloader=valid_loader, criterion=criterion,
#      21                                      epoch=epoch)
#      23     history['Train Loss'].append(train_epoch_loss)
#
# Cell In[147], line 54, in train_one_epoch(model, optimizer, criterion, scheduler, dataloader, epoch)
#      51     epoch_auroc = running_auroc / dataset_size
#      52     epoch_f1 = running_f1 / dataset_size
# ---> 54     bar.set_postfix(Epoch=epoch, Train_Loss=epoch_loss, Train_Auroc=epoch_auroc, Train_F1=epoch_f1,
#      55                     LR=optimizer.param_groups[0]['lr'])
#      56 gc.collect()
#      58 return epoch_loss, epoch_auroc, epoch_f1
#
# File ~/anaconda3/envs/DTMS/lib/python3.8/site-packages/tqdm/std.py:1431, in tqdm.set_postfix(self, ordered_dict, refresh, **kwargs)
#    1428 self.postfix = ', '.join(key + '=' + postfix[key].strip()
#    1429                          for key in postfix.keys())
#    1430 if refresh:
# -> 1431     self.refresh()
#
# File ~/anaconda3/envs/DTMS/lib/python3.8/site-packages/tqdm/std.py:1347, in tqdm.refresh(self, nolock, lock_args)
#    1345     else:
#    1346         self._lock.acquire()
# -> 1347 self.display()
#    1348 if not nolock:
#    1349     self._lock.release()
#
# File ~/anaconda3/envs/DTMS/lib/python3.8/site-packages/tqdm/std.py:1495, in tqdm.display(self, msg, pos)
#    1493 if pos:
#    1494     self.moveto(pos)
# -> 1495 self.sp(self.__str__() if msg is None else msg)
#    1496 if pos:
#    1497     self.moveto(-pos)
#
# File ~/anaconda3/envs/DTMS/lib/python3.8/site-packages/tqdm/std.py:459, in tqdm.status_printer.<locals>.print_status(s)
#     457 def print_status(s):
#     458     len_s = disp_len(s)
# --> 459     fp_write('\r' + s + (' ' * max(last_len[0] - len_s, 0)))
#     460     last_len[0] = len_s
#
# File ~/anaconda3/envs/DTMS/lib/python3.8/site-packages/tqdm/std.py:452, in tqdm.status_printer.<locals>.fp_write(s)
#     451 def fp_write(s):
# --> 452     fp.write(str(s))
#     453     fp_flush()
#
# File ~/anaconda3/envs/DTMS/lib/python3.8/site-packages/tqdm/utils.py:196, in DisableOnWriteError.disable_on_exception.<locals>.inner(*args, **kwargs)
#     194 def inner(*args, **kwargs):
#     195     try:
# --> 196         return func(*args, **kwargs)
#     197     except OSError as e:
#     198         if e.errno != 5:
#
# File ~/anaconda3/envs/DTMS/lib/python3.8/site-packages/wandb/sdk/lib/redirect.py:643, in StreamRawWrapper.install.<locals>.write(data)
#     641 for cb in self.cbs:
#     642     try:
# --> 643         cb(data)
#     644     except Exception:
#     645         # TODO: Figure out why this was needed and log or error out appropriately
#     646         # it might have been strange terminals? maybe shutdown cases?
#     647         pass
#
# File ~/anaconda3/envs/DTMS/lib/python3.8/site-packages/wandb/sdk/wandb_run.py:2163, in Run._redirect.<locals>.<lambda>(data)
#    2153     logger.info("Wrapping output streams.")
#    2154     out_redir = redirect.StreamRawWrapper(
#    2155         src="stdout",
#    2156         cbs=[
#    2157             lambda data: self._console_raw_callback("stdout", data),
#    2158         ],
#    2159     )
#    2160     err_redir = redirect.StreamRawWrapper(
#    2161         src="stderr",
#    2162         cbs=[
# -> 2163             lambda data: self._console_raw_callback("stderr", data),
#    2164         ],
#    2165     )
#    2166 elif console == "off":
#    2167     return
#
# File ~/anaconda3/envs/DTMS/lib/python3.8/site-packages/wandb/sdk/wandb_run.py:371, in _run_decorator._noop_on_finish.<locals>.decorator_fn.<locals>.wrapper_fn(self, *args, **kwargs)
#     368 @functools.wraps(func)
#     369 def wrapper_fn(self: Type["Run"], *args: Any, **kwargs: Any) -> Any:
#     370     if not getattr(self, "_is_finished", False):
# --> 371         return func(self, *args, **kwargs)
#     373     default_message = (
#     374         f"Run ({self.id}) is finished. The call to `{func.__name__}` will be ignored. "
#     375         f"Please make sure that you are using an active run."
#     376     )
#     377     resolved_message = message or default_message
#
# File ~/anaconda3/envs/DTMS/lib/python3.8/site-packages/wandb/sdk/wandb_run.py:1493, in Run._console_raw_callback(self, name, data)
#    1490     return
#    1492 if self._backend and self._backend.interface:
# -> 1493     self._backend.interface.publish_output_raw(name, data)
#
# File ~/anaconda3/envs/DTMS/lib/python3.8/site-packages/wandb/sdk/interface/interface.py:638, in InterfaceBase.publish_output_raw(self, name, data)
#     636     print("unknown type")
#     637 o = pb.OutputRawRecord(output_type=otype, line=data)
# --> 638 o.timestamp.GetCurrentTime()
#     639 self._publish_output_raw(o)
#
# File ~/anaconda3/envs/DTMS/lib/python3.8/site-packages/google/protobuf/internal/well_known_types.py:174, in Timestamp.GetCurrentTime(self)
#     172 def GetCurrentTime(self):
#     173   """Get the current UTC into Timestamp."""
# --> 174   self.FromDatetime(datetime.datetime.utcnow())
#
# File ~/anaconda3/envs/DTMS/lib/python3.8/site-packages/google/protobuf/internal/well_known_types.py:242, in Timestamp.FromDatetime(self, dt)
#     238   else:
#     239     # Note the tz conversion has to come after the timedelta arithmetic.
#     240     return (_EPOCH_DATETIME_AWARE + delta).astimezone(tzinfo)
# --> 242 def FromDatetime(self, dt):
#     243   """Converts datetime to Timestamp.
#     244
#     245   Args:
#     246     dt: A datetime. If it's timezone-naive, it's assumed to be in UTC.
#     247   """
#     248   # Using this guide: http://wiki.python.org/moin/WorkingWithTime
#     249   # And this conversion guide: http://docs.python.org/library/time.html
#     250
#    (...)
#     253   # struct_time to long, the source date in UTC, and so it follows that the
#     254   # correct transformation is calendar.timegm()
#
# KeyboardInterrupt:

# %% [markdown]
# # Plotting training metrics

# %%
def plot_metrics(metrics_dict):
    epochs = range(1, len(metrics_dict['Train Loss']) + 1)
    
    # Create a figure with subplots
    fig, axs = plt.subplots(3, 1, figsize=(10, 15), sharex=True)

    # Plot Train and Validation Loss
    axs[0].plot(epochs, metrics_dict['Train Loss'], label='Train Loss', color='blue', marker='o')
    axs[0].plot(epochs, metrics_dict['Valid Loss'], label='Valid Loss', color='orange', marker='o')
    axs[0].set_title('Loss Over Epochs')
    axs[0].set_ylabel('Loss')
    axs[0].legend()
    axs[0].grid()

    # Plot Train and Validation AUROC
    axs[1].plot(epochs, metrics_dict['Train AUROC'], label='Train AUROC', color='green', marker='o')
    axs[1].plot(epochs, metrics_dict['Valid AUROC'], label='Valid AUROC', color='red', marker='o')
    axs[1].set_title('AUROC Over Epochs')
    axs[1].set_ylabel('AUROC Score')
    axs[1].legend()
    axs[1].grid()

    
    # Plot Validation F1 Score
    axs[2].plot(epochs, metrics_dict['Valid F1'], label='Valid F1 Score', color='purple', marker='o')
    axs[2].set_title('Validation F1 Score Over Epochs')
    axs[2].set_ylabel('F1 Score')
    
    
    # Create a separate plot for Learning Rate
    fig_lr, ax_lr = plt.subplots(figsize=(10, 5))
    ax_lr.plot(epochs, metrics_dict['lr'], label='Learning Rate', color='cyan', linestyle='--', marker='o')
    ax_lr.set_title('Learning Rate Over Epochs')
    ax_lr.set_ylabel('Learning Rate')
    ax_lr.grid()
    fontsize = 12
    # Label points for each plot
    for i in range(0, len(metrics_dict['lr']), 10):
        axs[0].text(epochs[i], metrics_dict['Train Loss'][i], f"{metrics_dict['Train Loss'][i]:.2f}", 
                    fontsize=fontsize, ha='right', color='k')
        axs[0].text(epochs[i], metrics_dict['Valid Loss'][i], f"{metrics_dict['Valid Loss'][i]:.2f}", 
                    fontsize=fontsize, ha='right', color='k')
        
        axs[1].text(epochs[i], metrics_dict['Train AUROC'][i], f"{metrics_dict['Train AUROC'][i]:.2f}", 
                    fontsize=fontsize, ha='right', color='k')
        axs[1].text(epochs[i], metrics_dict['Valid AUROC'][i], f"{metrics_dict['Valid AUROC'][i]:.2f}", 
                    fontsize=fontsize, ha='right', color='k')

        axs[2].text(epochs[i], metrics_dict['Valid F1'][i], f"{metrics_dict['Valid F1'][i]:.2f}", 
                    fontsize=fontsize, ha='right', color='k')

        ax_lr.text(epochs[i], metrics_dict['lr'][i], f"{metrics_dict['lr'][i]:.4f}", 
                   fontsize=fontsize, ha='right', color='k')

    # Set common x-label
    axs[-1].set_xlabel('Epochs')
    
    plt.tight_layout()
    
    # Show plots
    plt.show()

# %%
plot_metrics(history)

# %%
val_epoch_loss, val_epoch_auroc, val_epoch_f1 = valid_one_epoch(model=model, dataloader=test_loader, criterion=criterion, 
                                         epoch=epoch)

# %%
torch.softmax(model(gt.to(CONFIG['device']), pred.to(CONFIG['device'])), dim=1)

# %% [markdown]
# # Test
